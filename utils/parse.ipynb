# %%
# %load_ext autoreload
# %autoreload 2

# %%
from parse import State, Hand, Session

# %%
file_path = '../pluribus/30'

session = Session(file_path)
session.parse()

print(session.hands[0])
# Out:
# Hand(player_positions={'p1': 'MrWhite', 'p2': 'Gogo', 'p3': 'Budd', 'p4': 'Eddie', 'p5': 'Bill', 'p6': 'Pluribus'},
# hole_cards={'p1': '3c9s', 'p2': '6d5s', 'p3': '9dTs', 'p4': '2sQs', 'p5': 'AdKd', 'p6': '7cTc'},
# starting_stacks={'p1': 10000, 'p2': 10000, 'p3': 10000, 'p4': 10000, 'p5': 10000, 'p6': 10000},
# states={'pre-flop': [State(community_cards=,
# betting_history=[],
# player_to_act=p3,
# players_in_hand=[('p1', True), ('p2', True), ('p3', True), ('p4', True), ('p5', True), ('p6', True)],
# current_stacks={'p1': 9950, 'p2': 9900, 'p3': 10000, 'p4': 10000, 'p5': 10000, 'p6': 10000},
# pot_size=150)
# , State(community_cards=,
# betting_history=[('p3', 'f', 0)],
# player_to_act=p4,
# players_in_hand=[('p1', True), ('p2', True), ('p3', False), ('p4', True), ('p5', True), ('p6', True)],
# current_stacks={'p1': 9950, 'p2': 9900, 'p3': 10000, 'p4': 10000, 'p5': 10000, 'p6': 10000},
# pot_size=150)
# , State(community_cards=,
# betting_history=[('p3', 'f', 0), ('p4', 'f', 0)],
# player_to_act=p5,
# players_in_hand=[('p1', True), ('p2', True), ('p3', False), ('p4', False), ('p5', True), ('p6', True)],
# current_stacks={'p1': 9950, 'p2': 9900, 'p3': 10000, 'p4': 10000, 'p5': 10000, 'p6': 10000},
# pot_size=150)
# , State(community_cards=,
# betting_history=[('p3', 'f', 0), ('p4', 'f', 0), ('p5', 'cbr', 225)],
# player_to_act=p6,
# players_in_hand=[('p1', True), ('p2', True), ('p3', False), ('p4', False), ('p5', True), ('p6', True)],
# current_stacks={'p1': 9950, 'p2': 9900, 'p3': 10000, 'p4': 10000, 'p5': 9775, 'p6': 10000},
# pot_size=375)
# , State(community_cards=,
# betting_history=[('p3', 'f', 0), ('p4', 'f', 0), ('p5', 'cbr', 225), ('p6', 'f', 0)],
# player_to_act=p1,
# players_in_hand=[('p1', True), ('p2', True), ('p3', False), ('p4', False), ('p5', True), ('p6', False)],
# current_stacks={'p1': 9950, 'p2': 9900, 'p3': 10000, 'p4': 10000, 'p5': 9775, 'p6': 10000},
# pot_size=375)
# , State(community_cards=,
# betting_history=[('p3', 'f', 0), ('p4', 'f', 0), ('p5', 'cbr', 225), ('p6', 'f', 0), ('p1', 'f', 0)],
# player_to_act=p2,
# players_in_hand=[('p1', False), ('p2', True), ('p3', False), ('p4', False), ('p5', True), ('p6', False)],
# current_stacks={'p1': 9950, 'p2': 9900, 'p3': 10000, 'p4': 10000, 'p5': 9775, 'p6': 10000},
# pot_size=375)
# , State(community_cards=,
# betting_history=[('p3', 'f', 0), ('p4', 'f', 0), ('p5', 'cbr', 225), ('p6', 'f', 0), ('p1', 'f', 0), ('p2', 'f', 0)],
# player_to_act=p5,
# players_in_hand=[('p1', False), ('p2', False), ('p3', False), ('p4', False), ('p5', True), ('p6', False)],
# current_stacks={'p1': 9950, 'p2': 9900, 'p3': 10000, 'p4': 10000, 'p5': 9775, 'p6': 10000},
# pot_size=375)
# ], 'flop': [], 'turn': [], 'river': []},
# actions={'pre-flop': {0: ('p3', 'f', 0), 1: ('p4', 'f', 0), 2: ('p5', 'cbr', 225), 3: ('p6', 'f', 0), 4: ('p1', 'f', 0), 5: ('p2', 'f', 0)}, 'flop': {}, 'turn': {}, 'river': {}})
