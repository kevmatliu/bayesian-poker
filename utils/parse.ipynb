# %%
# %load_ext autoreload
# %autoreload 2

# %%
from parse import State, Hand, Session

# %%
file_path = '../pluribus/30'

session = Session(file_path)
session.parse()

print(session.hands[31])
# Out:
# Hand(player_positions={'p1': 'Gogo', 'p2': 'Budd', 'p3': 'Eddie', 'p4': 'Bill', 'p5': 'Pluribus', 'p6': 'MrWhite'},
# hole_cards={'p1': 'Js4h', 'p2': '7h5h', 'p3': 'TcTd', 'p4': '6c4c', 'p5': 'Kc6s', 'p6': 'Kh6h'},
# starting_stacks={'p1': 10000, 'p2': 10000, 'p3': 10000, 'p4': 10000, 'p5': 10000, 'p6': 10000},
# states={'pre-flop': [State(community_cards=,
# betting_history=[],
# player_to_act=p3,
# players_in_hand=[('p1', True), ('p2', True), ('p3', True), ('p4', True), ('p5', True), ('p6', True)],
# current_stacks={'p1': 9950, 'p2': 9900, 'p3': 10000, 'p4': 10000, 'p5': 10000, 'p6': 10000},
# pot_size=150,
# hand_strength_map={'p1': None, 'p2': None, 'p3': None, 'p4': None, 'p5': None, 'p6': None})
# , State(community_cards=,
# betting_history=[('p3', (3, 1), 200)],
# player_to_act=p4,
# players_in_hand=[('p1', True), ('p2', True), ('p3', True), ('p4', True), ('p5', True), ('p6', True)],
# current_stacks={'p1': 9950, 'p2': 9900, 'p3': 9800, 'p4': 10000, 'p5': 10000, 'p6': 10000},
# ...
