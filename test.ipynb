# %%
feature_names = [
    "bias",
    "made",
    "draw",
    "made_x_draw",
    "polar_m",
    "bet_frac_pot",
    "pot_odds",
    "in_position",
    "multiway",
    "log_1_plus_spr",
    "street_turn",
    "street_river",
    "board_wetness",
    "is_pair_or_better",
    "is_top_pair",
    "is_over_pair",
    "is_middle_pair",
    "is_under_pair",
    "is_two_pair_plus",
    "is_set_or_better",
    "is_straight_or_better",
    "has_flush_draw",
    "has_oesd",
    "has_gutshot",
    "is_suited",
    "is_pocket_pair",
    "overcard_count",
    "blocks_top_pair",
    "blocks_nut_flush",
    "equity"
]

# %%
for i in range(len(feature_names)):
    if "_" in feature_names[i]:
        feature_names[i] = feature_names[i].replace("_", "\\_")

print(", ".join(feature_names))
# Out:
# bias, made, draw, made\_x\_draw, polar\_m, bet\_frac\_pot, pot\_odds, in\_position, multiway, log\_1\_plus\_spr, street\_turn, street\_river, board\_wetness, is\_pair\_or\_better, is\_top\_pair, is\_over\_pair, is\_middle\_pair, is\_under\_pair, is\_two\_pair\_plus, is\_set\_or\_better, is\_straight\_or\_better, has\_flush\_draw, has\_oesd, has\_gutshot, is\_suited, is\_pocket\_pair, overcard\_count, blocks\_top\_pair, blocks\_nut\_flush, equity

# %%
', '.join(feature_names)
# Out:
# 'bias, made, draw, made_x_draw, polar_m, bet_frac_pot, pot_odds, in_position, multiway, log_1_plus_spr, street_turn, street_river, board_wetness, is_pair_or_better, is_top_pair, is_over_pair, is_middle_pair, is_under_pair, is_two_pair_plus, is_set_or_better, is_straight_or_better, has_flush_draw, has_oesd, has_gutshot, is_suited, is_pocket_pair, overcard_count, blocks_top_pair, blocks_nut_flush, equity'
